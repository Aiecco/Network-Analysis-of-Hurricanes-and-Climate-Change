# %% [markdown]
# # TikTok imports

# %%
import pandas as pd
import matplotlib as plt
from matplotlib import pyplot as plt
import time
from tqdm.auto import tqdm

import requests
from datetime import datetime

# %%
from ensembledata.api import EDClient

# %%
# initialize the ensembledata client
client = EDClient("M2OK8yIEX5UjTkfA")

# get a free token at https://dashboard.ensembledata.com/register
# free trial of 50 units per day for 7 days, starting 23/11/24
#
# costs:
#  - 1 unit = 200 posts in full_hashtag_search :)
#  - 1 unit = 20 posts in hashtag_search
#  - 1 unit = 20 posts in keyword_search or full_keyword_search :(
#  - 1 unit = 30 comments to a post
#  - 1 unit = 30 replies to a comment
#
# documentation available at https://ensembledata.com/apis/docs#tag/Tiktok
# and https://github.com/EnsembleData/tiktok-scraper
# source code available at
# https://github.com/EnsembleData/ensembledata-python/tree/main/ensembledata/api

# %% [markdown]
# # Read posts from TikTok

# %% [markdown]
# Hashtag search (200 posts at the cost of 1 unit)

# %%
# read posts related to a hashtag
result = client.tiktok.full_hashtag_search(
                hashtag = "hurricaneidalia", # hashtag name
                days = 550,   # ADJUST FOR HURRICANE DATE !!!!!!
                remap_output = True, # False for mobile app, True for web
                max_cursor = 4000) # max number of posts fetched,
                                  # cost is 1 unit per 200 posts

# %%
# convert json to dataframe
df = pd.json_normalize(result.data["posts"])

# %%
# extract relevant info
df = df[['itemInfos.id', 'itemInfos.createTime', 'itemInfos.authorId',
         'itemInfos.text', 'itemInfos.video.urls', 'itemInfos.shareCount',
         'itemInfos.playCount', 'itemInfos.commentCount']]

# rename columns
df.columns = ['id', 'createTime', 'authorId', 'text', 'video.urls',
              'shareCount', 'playCount', 'commentCount']

# format time to date in string format
df["createTime"] = [str(datetime.fromtimestamp(int(i)).date())
                                                for i in df["createTime"]]

# %%
df = df.sort_values(by=['createTime'], ascending=True).reset_index(drop=True)
df
# Out:
#                        id  createTime             authorId  \
# 0     7271051377613212971  2023-08-25  7097557512820393003
# 1     7271080230721277227  2023-08-25  6788321418486170630
# 2     7271643255589080362  2023-08-26  6782720514957067269
# 3     7271413452378230062  2023-08-26  6782720514957067269
# 4     7271737498571722026  2023-08-26  6725787885481821190
# ...                   ...         ...                  ...
# 3308  7423455155091410222  2024-10-08  7191602200883364910
# 3309  7423879220591480095  2024-10-09  6976471700804895749
# 3310  7424503338349137194  2024-10-11  7385435642845365290
# 3311  7427928272144551211  2024-10-20  7384909845448770603
# 3312  7446088930484571422  2024-12-08  7332952767382225962
#
#                                                    text  \
# 0     hurricane idalia 2023 #florida #hurricane #tro...
# 1     #herewego #hurricane #hurricaneidalia #hereweg...
# 2     #TropicalStormIdalia likely to form over the n...
# 3     Don’t turn your back on the Gulf in late Augus...
# 4            #hurricane #florida #hurricaneidalia #fyp
# ...                                                 ...
# 3308  The Weird Reason Hurricanes Have Names 😲🌪️ #Hu...
# 3309  Praying for everyone affected by Hurricane Mil...
# 3310  my hurricane idalia experience! Hurricane Idal...
# 3311  Lol #hurricanemilton #hurricanehelene #hurrica...
# 3312  🏆 Este Emmy no es solo un reconocimiento al tr...
#
#                                              video.urls  shareCount  \
# 0     [https://api16-normal-c-useast2a.tiktokv.com/a...          19
# 1     [https://api16-normal-c-useast2a.tiktokv.com/a...          50
# 2     [https://v77.tiktokcdn-eu.com/3f5d6325e016b9ab...        1440
# 3     [https://api16-normal-c-useast2a.tiktokv.com/a...         413
# 4     [https://api16-normal-c-useast2a.tiktokv.com/a...          31
# ...                                                 ...         ...
# 3308  [https://api16-normal-c-useast2a.tiktokv.com/a...           6
# 3309  [https://sf16-ies-music-sg.tiktokcdn.com/obj/t...           0
# 3310  [https://api16-normal-c-useast2a.tiktokv.com/a...         105
# 3311  [https://api16-normal-c-useast2a.tiktokv.com/a...          41
# 3312  [https://v15m-perf.tiktokcdn-eu.com/06ba34dd7d...          79
#
#       playCount  commentCount
# 0         12697            36
# 1         22142             8
# 2        142843           286
# 3        114357           108
# 4         28254            18
# ...         ...           ...
# 3308       5980             6
# 3309       2226             0
# 3310     321033            48
# 3311      97231           127
# 3312      24331           583
#
# [3313 rows x 8 columns]

# %%
for i in range(len(df)):
  if df["createTime"][i]<"2023-08-25":
    df=df.drop(i)
  if df["createTime"][i]>"2023-10-9":
    df=df.drop(i)

# %%
# order by comment count
df = df.sort_values(by=['commentCount'], ascending=False).reset_index(drop=True)

# delete posts with less than 30 comments
df = df[df['commentCount'] >= 30]

# state how many
print(f'{len(df)} posts for hashtags with more than 30 comments')
# Out:
# 1087 posts for hashtags with more than 30 comments

# %%
df['createTime'].unique()
# Out:
# array(['2023-08-27', '2023-08-31', '2023-08-30', '2023-08-29',
#        '2023-08-28', '2023-09-26', '2023-10-09', '2023-09-02',
#        '2023-09-17', '2023-09-01', '2023-09-30', '2023-10-05',
#        '2023-09-07', '2023-09-04', '2023-10-04', '2023-09-05',
#        '2023-09-22', '2023-08-26', '2023-10-24', '2023-09-25',
#        '2023-09-14', '2023-09-03', '2023-10-03', '2023-09-16',
#        '2023-09-11', '2023-10-20', '2023-09-09', '2023-09-10',
#        '2023-09-12', '2023-09-08', '2023-09-06', '2023-08-25',
#        '2023-09-20'], dtype=object)

# %%
len(df['createTime'].unique())  # we take the comments of x days
# Out:
# 33

# %%
df = df.loc[df.groupby('createTime')['commentCount'].idxmax()]

# %%
# order df by date
df = df.sort_values(by=['createTime'], ascending=True).reset_index(drop=True)

df
# Out:
#                      id  createTime             authorId  \
# 0   7271051377613212971  2023-08-25  7097557512820393003
# 1   7271643255589080362  2023-08-26  6782720514957067269
# 2   7272071106490600747  2023-08-27  6966634939376157702
# 3   7272389824391269674  2023-08-28  6787453173931852805
# 4   7272535297378766123  2023-08-29  6790813865506636805
# 5   7273191672803101994  2023-08-30  6610797907615940613
# 6   7273270653707390241  2023-08-31  7239587261129704454
# 7   7273620466760305963  2023-09-01  7176441536266404907
# 8   7274007768485367083  2023-09-02  6847548206487340038
# 9   7274413941835681070  2023-09-03  6808945376549962758
# 10  7274754300415331627  2023-09-04  6982026074398180357
# 11  7275361522988207402  2023-09-05  6982026074398180357
# 12  7275725114228903211  2023-09-06  6818543154599085062
# 13  7276160111658388782  2023-09-07  7184842974696752174
# 14  7276212349919415595  2023-09-08  7272143296222315563
# 15  7276844029503868206  2023-09-09  6982026074398180357
# 16  7277216107105307950  2023-09-10  6982026074398180357
# 17  7277567759129824517  2023-09-11  6567425897153462277
# 18  7277963002773556522  2023-09-12  6982026074398180357
# 19  7278723481032756513  2023-09-14  7239587261129704454
# 20  7279445468688567598  2023-09-16  6982026074398180357
# 21  7279835249553476896  2023-09-17  7239587261129704454
# 22  7280736939672718634  2023-09-20  6768939939091760133
# 23  7281445797936336160  2023-09-22  7239587261129704454
# 24  7282609593287593248  2023-09-25  7239587261129704454
# 25  7282930375540608289  2023-09-26  7239587261129704454
# 26  7284407922543643936  2023-09-30  7239587261129704454
# 27  7285526647867034912  2023-10-03  7239587261129704454
# 28  7286175230114975009  2023-10-04  7239587261129704454
# 29  7286557451015425313  2023-10-05  7239587261129704454
# 30  7288021537909787937  2023-10-09  7239587261129704454
# 31  7292036111130430750  2023-10-20  7082891832002692139
# 32  7293469706407677214  2023-10-24  7082891832002692139
#
#                                                  text  \
# 0   hurricane idalia 2023 #florida #hurricane #tro...
# 1   #TropicalStormIdalia likely to form over the n...
# 2   The arrogance and flippant attitude of some of...
# 3   #denisphillips #hurricaneidalia 🌀#jennysellsth...
# 4   Please dont drain your pool! Praying for all m...
# 5   White House Press Secretary Karine Jean-Pierre...
# 6   In seconds, the Idalia tsunami formed #idalia ...
# 7   Makes me sad that out of all the cars that cou...
# 8   The Florida governor rejected millions in clim...
# 9   President Biden represents all Americans. He s...
# 10  🤔🤔 #greenscreen #dogsofttiktok #dontbullymybre...
# 11  Showing Naomi baby Solo one more time🥺🥺 #dogso...
# 12  #duet with @FL Edition #voteblue #fyp #fup #th...
# 13  From Florida to Ohio, an unusual and beautiful...
# 14  AVENGE ME @Hurricane Lee AND HIT FLORIDA 🗣️🗣️🗣...
# 15  🤭😭 HaHaHa!! #dogsofttiktok #dontbullymybreed #...
# 16  Let me go pray🙏🏽😔 #dogsofttiktok #dontbullymyb...
# 17  #Oops, it happened again… #rhodeisland #hurric...
# 18  Training Makes Perfect‼️ ##dogsofttiktok##dont...
# 19  Oh my God, this is where the tsunami started, ...
# 20  😡🗣️ TOKYOOO‼️ ##dogsofttiktok##dontbullymybree...
# 21  In seconds, the massive Florida tsunami formed...
# 22  #river #homosassa #water #hurricaneidalia #for...
# 23  From here the disaster began #tsunami #idalia ...
# 24  Within seconds, the Florida tsunami formed #po...
# 25  In pochi secondi si formò l’enorme tsunami del...
# 26  Major floods in Brooklyn, New York USA, 29/09/...
# 27  Mira como en un segundo este tornado acabó con...
# 28  All these disasters happened in America 2023 #...
# 29  Inondations le 5 octobre 2023 #idalia #tropics...
# 30  C'était comme si la chaleur en France et en Es...
# 31  #evil #charlottecountyflorida #isreal #america...
# 32  #msnbc #fox #cnn #isreal #charlotte #charlotte...
#
#                                            video.urls  shareCount  playCount  \
# 0   [https://api16-normal-c-useast2a.tiktokv.com/a...          19      12697
# 1   [https://v77.tiktokcdn-eu.com/3f5d6325e016b9ab...        1440     142843
# 2   [https://api16-normal-c-useast2a.tiktokv.com/a...        7031     673424
# 3   [https://v77.tiktokcdn-eu.com/723e5c9464024a9e...        1728    1301460
# 4   [https://v45.tiktokcdn-eu.com/83c7d73aac2a9cf1...       11233   26980257
# 5   [https://api16-normal-c-useast2a.tiktokv.com/a...         590     504711
# 6   [https://api16-normal-c-useast2a.tiktokv.com/a...       19893   16468067
# 7   [https://api16-normal-c-useast2a.tiktokv.com/a...        5710     531473
# 8   [https://v16m.tiktokcdn-eu.com/69a72e4fde39a61...        1486     113686
# 9   [https://api16-normal-c-useast2a.tiktokv.com/a...          59      52421
# 10  [https://api16-normal-c-useast2a.tiktokv.com/a...           5      17589
# 11  [https://v15m.tiktokcdn-eu.com/3f14c929d8f5a0f...         104     124546
# 12  [https://api16-normal-c-useast2a.tiktokv.com/a...           7       6037
# 13  [https://v16m.tiktokcdn-eu.com/a183188c2143923...        9533     634333
# 14  [https://sf16-ies-music-va.tiktokcdn.com/obj/m...          27       7288
# 15  [https://api16-normal-c-useast2a.tiktokv.com/a...          10      11854
# 16  [https://v45.tiktokcdn-eu.com/2d20952807792c41...          24      15064
# 17  [https://api16-normal-c-useast2a.tiktokv.com/a...         983      49661
# 18  [https://api16-normal-c-useast2a.tiktokv.com/a...          18      14556
# 19  [https://api16-normal-c-useast2a.tiktokv.com/a...        1743     842514
# 20  [https://v16m.tiktokcdn-eu.com/4e15b5b2d34d33d...          31      19443
# 21  [https://v16m.tiktokcdn-eu.com/b6ca1d78e2a280a...        4239    1415168
# 22  [https://v77.tiktokcdn-eu.com/d86a10e0bf23cedf...          57      12548
# 23  [https://api16-normal-c-useast2a.tiktokv.com/a...        1827     680551
# 24  [https://api16-normal-c-useast2a.tiktokv.com/a...        1257    1530887
# 25  [https://v77.tiktokcdn-eu.com/b9e82db7e7d3290b...        3440    3213361
# 26  [https://v77.tiktokcdn-eu.com/8fea46ff4d362d2a...        5129     976354
# 27  [https://v77.tiktokcdn-eu.com/4faf461694d22d34...         409     731240
# 28  [https://v77.tiktokcdn-eu.com/c5499391dc5f1ec1...         892     580573
# 29  [https://api16-normal-c-useast2a.tiktokv.com/a...        2672     554385
# 30  [https://api16-normal-c-useast2a.tiktokv.com/a...       14068    3189296
# 31  [https://v16m.tiktokcdn-eu.com/6833c577883cfdf...          69      27973
# 32  [https://v77-perf.tiktokcdn-eu.com/5a8fde2243a...         198      28646
#
#     commentCount
# 0             36
# 1            286
# 2           5197
# 3           1931
# 4           3796
# 5           3964
# 6           4096
# 7            892
# 8           1105
# 9            199
# 10           442
# 11           332
# 12            37
# 13           759
# 14            57
# 15            59
# 16            59
# 17           108
# 18            58
# 19           213
# 20           134
# 21           915
# 22            34
# 23           327
# 24           265
# 25          1466
# 26           869
# 27           171
# 28           349
# 29           763
# 30          1258
# 31            91
# 32           266

# %%
df.to_csv('idalia_posts.csv', index=False)
