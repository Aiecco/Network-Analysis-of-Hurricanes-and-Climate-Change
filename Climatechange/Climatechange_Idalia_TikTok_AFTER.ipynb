# %% [markdown]
# # TikTok imports

# %%
import pandas as pd
import matplotlib as plt
from matplotlib import pyplot as plt
import time
from tqdm.auto import tqdm

import requests
from datetime import datetime

# %%
from ensembledata.api import EDClient

# %%
# initialize the ensembledata client
client = EDClient("M2OK8yIEX5UjTkfA")

# get a free token at https://dashboard.ensembledata.com/register
# free trial of 50 units per day for 7 days, starting 23/11/24
#
# costs:
#  - 1 unit = 200 posts in full_hashtag_search :)
#  - 1 unit = 20 posts in hashtag_search
#  - 1 unit = 20 posts in keyword_search or full_keyword_search :(
#  - 1 unit = 30 comments to a post
#  - 1 unit = 30 replies to a comment
#
# documentation available at https://ensembledata.com/apis/docs#tag/Tiktok
# and https://github.com/EnsembleData/tiktok-scraper
# source code available at
# https://github.com/EnsembleData/ensembledata-python/tree/main/ensembledata/api

# %% [markdown]
# # Read posts from TikTok

# %% [markdown]
# Hashtag search (200 posts at the cost of 1 unit)

# %%
# read posts related to a hashtag
result = client.tiktok.full_hashtag_search(
                hashtag = "climatechange", # hashtag name
                days = 900,   # ADJUST FOR HURRICANE DATE !!!!!!
                remap_output = True, # False for mobile app, True for web
                max_cursor = 3500) # max number of posts fetched,
                                  # cost is 1 unit per 200 posts

# %%
# convert json to dataframe
df = pd.json_normalize(result.data["posts"])

# %%
# extract relevant info
df = df[['itemInfos.id', 'itemInfos.createTime', 'itemInfos.authorId',
         'itemInfos.text', 'itemInfos.video.urls', 'itemInfos.shareCount',
         'itemInfos.playCount', 'itemInfos.commentCount']]

# rename columns
df.columns = ['id', 'createTime', 'authorId', 'text', 'video.urls',
              'shareCount', 'playCount', 'commentCount']

df["createTime"] = [str(datetime.fromtimestamp(int(i)).date())
                                                for i in df["createTime"]]

# %%
df
# Out:
#                        id  createTime             authorId  \
# 0     7437818533284760865  2024-11-16  7303599367192478753
# 1     7378264093779692843  2024-06-09  6583142791119306758
# 2     7206613856376933634  2023-03-04  7120349466079151106
# 3     7329576474367773994  2024-01-29  6714257599150326790
# 4     7437892758251113784  2024-11-16  7034404685826556933
# ...                   ...         ...                  ...
# 1688  7148527284805455150  2022-09-28  6829111343543649285
# 1689  7247170518816787738  2023-06-21  6846128426316678149
# 1690  7252884311345515781  2023-07-07  6838681319300891653
# 1691  7227923557991369990  2023-04-30  6853621171482510341
# 1692  7359997061204397344  2024-04-20  6903623143736198146
#
#                                                    text  \
# 0     #climatechange #davidattenborough #globalwarmi...
# 1     Like be so f-ing for real guys #climatechange ...
# 2     Everyone can help! #climatechange #saveearth #...
# 3      interesting #climatechange & #MentalHealth story
# 4     #globalwarming #climatechange #polarbear #sad ...
# ...                                                 ...
# 1688  #stitch with @random_crow Fossil fuels are fin...
# 1689  Klima Aktivist vs Bergbauer🐻🐺 #climatechange #...
# 1690  Así reforma en estos momentos ⛈️ hasta aquí mi...
# 1691  "The Dirty Truth: Inadequate Support for Garba...
# 1692  Protesters gathered in Tenerife to rally again...
#
#                                              video.urls  shareCount  \
# 0     [https://v77.tiktokcdn-eu.com/475107103afd5873...      113841
# 1     [https://v77.tiktokcdn-eu.com/9f75fb30d0c4ce67...        5177
# 2     [https://v77.tiktokcdn-eu.com/3026176419e13d5c...       35715
# 3     [https://v77.tiktokcdn-eu.com/89dde4e87bc8b684...       12813
# 4     [https://v77.tiktokcdn-eu.com/e7d70e611d468e84...       13751
# ...                                                 ...         ...
# 1688  [https://v45.tiktokcdn-eu.com/3a8fb06be808988c...         161
# 1689  [https://v45.tiktokcdn-eu.com/26992ac15e32c0e6...        2259
# 1690  [https://v45.tiktokcdn-eu.com/354379225a32c071...        2804
# 1691  [https://v45.tiktokcdn-eu.com/338fbb965fa37220...        1338
# 1692  [https://v45.tiktokcdn-eu.com/837f2b22d9ba6604...        3654
#
#       playCount  commentCount
# 0      13831239         13536
# 1        955361          2782
# 2       2053641          5888
# 3       1933795          4107
# 4       1506710          2976
# ...         ...           ...
# 1688     212298           640
# 1689     415077           154
# 1690     949605           239
# 1691     256938          1257
# 1692     894521          2707
#
# [1693 rows x 8 columns]

# %%
df = df[(df["createTime"] >= "2023-10-09") & (df["createTime"] <= "2023-11-09")]

# %%
# order by comment count
df = df.sort_values(by=['commentCount'], ascending=False).reset_index(drop=True)

# delete posts with less than 30 comments
df = df[df['commentCount'] >= 30]

# state how many
print(f'{len(df)} posts for hashtags with more than 30 comments')
# Out:
# 75 posts for hashtags with more than 30 comments

# %%
df['createTime'].unique()
# Out:
# array(['2023-10-08', '2023-09-28', '2023-09-29', '2023-09-21',
#        '2023-09-05', '2023-09-20', '2023-09-06', '2023-09-08',
#        '2023-09-10', '2023-09-12', '2023-09-09', '2023-08-29',
#        '2023-10-06', '2023-09-03', '2023-09-07', '2023-10-01',
#        '2023-10-03', '2023-09-24', '2023-09-25', '2023-10-09',
#        '2023-09-01', '2023-09-04', '2023-09-19', '2023-10-02',
#        '2023-09-22', '2023-09-15', '2023-08-26', '2023-09-16',
#        '2023-09-30', '2023-10-05', '2023-09-13', '2023-10-04',
#        '2023-08-28', '2023-08-25', '2023-08-30', '2023-10-07',
#        '2023-09-23', '2023-09-26'], dtype=object)

# %%
len(df['createTime'].unique())  # we take the comments of x days
# Out:
# 38

# %%
df = df.loc[df.groupby('createTime')['commentCount'].idxmax()]

# %%
# order df by date
df = df.sort_values(by=['createTime'], ascending=True).reset_index(drop=True)

df
# Out:
#                      id  createTime             authorId  \
# 0   7271342302382148907  2023-08-25  6803462802675844101
# 1   7271410119622020395  2023-08-26  6777593631172838406
# 2   7272451010495302954  2023-08-28  7023454894796719110
# 3   7272820833368739114  2023-08-29  6724659169629340678
# 4   7273122381269617925  2023-08-30             19663988
# 5   7273854909378759969  2023-09-01  6970050888732279814
# 6   7274689988548185376  2023-09-03  7192662362943734789
# 7   7275083944171719979  2023-09-04  6668094621179428870
# 8   7275412673473514798  2023-09-05  6940967490765128710
# 9   7275799559224282374  2023-09-06  7165860667278279685
# 10  7275895775681400106  2023-09-07  6993899054099432453
# 11  7276434003060854062  2023-09-08  6989228497793729541
# 12  7276894831199145249  2023-09-09  7189305729990902789
# 13  7277317545454177582  2023-09-10  6978105312616793094
# 14  7277894454084685089  2023-09-12  6784399419476657157
# 15  7278285531702643969  2023-09-13  7132694900667089947
# 16  7279110551995813166  2023-09-15  6900571600115106821
# 17  7279350028651613442  2023-09-16  7110039826825741317
# 18  7280478920753958145  2023-09-19  6759397361699685381
# 19  7280983016686554410  2023-09-20  6808945376549962758
# 20  7281208819865144608  2023-09-21  7246430124304008218
# 21  7281621191889014048  2023-09-22  6811021642975036422
# 22  7281935325604171013  2023-09-23  7275741905153295362
# 23  7282351161590484230  2023-09-24  6636146052587388933
# 24  7282816128613649696  2023-09-25  7227928035647276059
# 25  7283138470149672224  2023-09-26  6819249571340846085
# 26  7283876381547695393  2023-09-28  6777419460829430790
# 27  7284316139633577259  2023-09-29  7218349606697911342
# 28  7284376210577149227  2023-09-30  6773864952156472325
# 29  7284797188264299818  2023-10-01  6819967169918878726
# 30  7285320931457649952  2023-10-02  6970050888732279814
# 31  7285526435232714030  2023-10-03  6707407786831856646
# 32  7285873395604917537  2023-10-04  6970050888732279814
# 33  7286289576493108523  2023-10-05  6948485597321823237
# 34  7286673402717424903  2023-10-06  6853403085029508097
# 35  7287257421683150113  2023-10-07  7183036802289271814
# 36  7287680374136786219  2023-10-08  6912615643208827909
# 37  7288021537909787937  2023-10-09  7239587261129704454
#
#                                                  text  \
# 0   Out with cars, in with bikes & public transit ...
# 1   #goodmorningbadnews #boomers #climate #climate...
# 2   Clear-air turbulence is becoming more frequent...
# 3   We talked to this guy on a record-setting hot ...
# 4   SKL Vid Ep. XXX: Is the Philippines the countr...
# 5   #anprimgang #anprimmemes #nature #naturelovers...
# 6   Explore what's happening to the climate. Suppo...
# 7   and weather says its about to rain again 🙃 #fy...
# 8   #greenscreenvideo #fyp #trending #facts #feeli...
# 9   #africaclimatesummit #african #africa #african...
# 10  #GoodClimateNews Today, we are a step closer t...
# 11  #pork #farming #agriculture #cattle #chickens ...
# 12  #climatechange #politics #taxpayers #senatorke...
# 13  Pay Attention to what you hear 🙏🏽🙏🏽#greenscree...
# 14  Eyewitness video shows police using a water ca...
# 15  Đường ngập mà chạy dữ zậy ông thần #daibachhoa...
# 16  2023 is another record-breaking year for globa...
# 17  The mountains🏔️have given us everything !! Tha...
# 18  I hope your ready for a record breaking summer...
# 19  This is how it’s done! Secretary of Transporta...
# 20  The ‘Blade Runners’ strike ULEZ cameras AGAIN ...
# 21  Is #RishiSunak just #making #things #up #now ?...
# 22  ekosistem ANTARTIKA terancam ??  #bungamekar #...
# 23            #Meme #climatechange #zelensky #canada
# 24  … #astronomy #space #universe #antarctica #mel...
# 25  Laterbase. #climatechange #peepshow #markcorri...
# 26  "How dare you." Watch as Greta Thunberg calls ...
# 27  There. I said it. 🌳 @CommonGroundFilm #followt...
# 28  This music calms my soul 💧 #nyc #nycflooding #...
# 29  The world isn't dying, we are. #climatechange ...
# 30  FAKE EVERYTHING #anprimgang #anprimmemes #natu...
# 31  This is a nightmare i have to suffer on repeat...
# 32  The scary fact is that for most of you this is...
# 33  When climate change somehow leads to cannibal!...
# 34  Climate change, Octupus running from sea 🌊  Re...
# 35  #💯 #💪 #volvo  #ypf ##tik_tok #swedishpower   #...
# 36  Kids arent even tall enough to pump gas. #pare...
# 37  C'était comme si la chaleur en France et en Es...
#
#                                            video.urls  shareCount  playCount  \
# 0   [https://sf16-music-sign.tiktokcdn.com/obj/tos...         932     393410
# 1   [https://v77.tiktokcdn-eu.com/ef7a54a6353bfd5a...        1811     365905
# 2   [https://v45.tiktokcdn-eu.com/5dc8a8e9d56c9171...        7324     765558
# 3   [https://v16m.tiktokcdn-eu.com/8df0ce1f5262a1c...        4840     942926
# 4   [https://v16m.tiktokcdn-eu.com/cf7b4626c39baf7...         581     486559
# 5   [https://sf16-ies-music-sg.tiktokcdn.com/obj/t...        2328    2154688
# 6   [https://v77.tiktokcdn-eu.com/a0b89f867a65ecb5...       21332    1677128
# 7   [https://v45.tiktokcdn-eu.com/d1460c1088874f88...        7612     909926
# 8   [https://v15m-perf.tiktokcdn-eu.com/cd82d4836b...        6872     259582
# 9   [https://v77.tiktokcdn-eu.com/4c794eb732d85c96...        4398    4156604
# 10  [https://v45.tiktokcdn-eu.com/0ef74c502c963160...       11204    1035121
# 11  [https://v45.tiktokcdn-eu.com/319624db5d0ac68b...       15480     412383
# 12  [https://v45.tiktokcdn-eu.com/ac60600777d437fb...        6531    2204509
# 13  [https://v45.tiktokcdn-eu.com/30bfda3f8eb0913f...       28805     675484
# 14  [https://v16m.tiktokcdn-eu.com/240a7105ecd08df...        1174    1514774
# 15  [https://v77.tiktokcdn-eu.com/825c2b256d26763a...        1060    2376594
# 16  [https://v15m.tiktokcdn-eu.com/5e7313574fa8a3d...        2358     814523
# 17  [https://v45.tiktokcdn-eu.com/5fec1f69f5e37301...         257     463502
# 18  [https://v45.tiktokcdn-eu.com/23f56298510144e7...        7219     430366
# 19  [https://v45.tiktokcdn-eu.com/0c92701ecbe1e09e...        4645    1432081
# 20  [https://v77.tiktokcdn-eu.com/b5952f507f09b241...        2369    1212157
# 21  [https://v58.tiktokcdn-eu.com/video/tos/useast...        2579     361789
# 22  [https://v77.tiktokcdn-eu.com/cb64a073e2de2a87...         870    1124856
# 23  [https://v16m.tiktokcdn-eu.com/d27ece8971cea14...        2148     664903
# 24  [https://sf16-ies-music-sg.tiktokcdn.com/obj/t...        3337     866562
# 25  [https://v77.tiktokcdn-eu.com/eb2fcb8b4f36b5dc...        3154     214162
# 26  [https://v45.tiktokcdn-eu.com/86ef68531c0ca6a6...        6450    2087147
# 27  [https://v45.tiktokcdn-eu.com/5180a19b94202758...       25442     762426
# 28  [https://v16m.tiktokcdn-eu.com/19208d0ddc39a9c...       22871     752384
# 29  [https://v45.tiktokcdn-eu.com/2e5040806f0f1de0...        1634     900974
# 30  [https://sf16-ies-music-sg.tiktokcdn.com/obj/t...        4437     686092
# 31  [https://v77.tiktokcdn-eu.com/638f5d3a1fe4afa0...        6586     633777
# 32  [https://sf16-music-sign.tiktokcdn.com/obj/tos...        1581     312475
# 33  [https://v16m.tiktokcdn-eu.com/1657ed8fd01acdc...        2404     326088
# 34  [https://v58.tiktokcdn-eu.com/video/tos/alisg/...       10211    2987345
# 35  [https://v58.tiktokcdn-eu.com/video/tos/useast...        7031    1773277
# 36  [https://v58.tiktokcdn-eu.com/video/tos/maliva...       29171    1947168
# 37  [https://v45.tiktokcdn-eu.com/c49153ae7f6ecaad...       14068    3189306
#
#     commentCount
# 0            364
# 1            728
# 2            565
# 3           2360
# 4            292
# 5           1207
# 6           2084
# 7           1174
# 8           4309
# 9           3209
# 10          2062
# 11          3142
# 12          2410
# 13          2775
# 14          2552
# 15           587
# 16           746
# 17           721
# 18          1128
# 19          3375
# 20          4908
# 21           878
# 22           188
# 23          1543
# 24          1261
# 25           171
# 26          6098
# 27          5746
# 28           691
# 29          1920
# 30          1034
# 31          1713
# 32           578
# 33           607
# 34          2299
# 35           277
# 36          7580
# 37          1258

# %%
df.to_csv('climatechange_idalia_posts.csv', index=False)
