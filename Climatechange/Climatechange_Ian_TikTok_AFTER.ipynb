# %% [markdown]
# # TikTok imports

# %%
import pandas as pd
import matplotlib as plt
from matplotlib import pyplot as plt
import time
from tqdm.auto import tqdm

import requests
from datetime import datetime

# %%
from ensembledata.api import EDClient

# %%
# initialize the ensembledata client
client = EDClient("tHMlAfSzgpDhxmFA")

# get a free token at https://dashboard.ensembledata.com/register
# free trial of 50 units per day for 7 days, starting 23/11/24
#
# costs:
#  - 1 unit = 200 posts in full_hashtag_search :)
#  - 1 unit = 20 posts in hashtag_search
#  - 1 unit = 20 posts in keyword_search or full_keyword_search :(
#  - 1 unit = 30 comments to a post
#  - 1 unit = 30 replies to a comment
#
# documentation available at https://ensembledata.com/apis/docs#tag/Tiktok
# and https://github.com/EnsembleData/tiktok-scraper
# source code available at
# https://github.com/EnsembleData/ensembledata-python/tree/main/ensembledata/api

# %% [markdown]
# # Read posts from TikTok

# %% [markdown]
# Hashtag search (200 posts at the cost of 1 unit)

# %%
# read posts related to a hashtag
result = client.tiktok.full_hashtag_search(
                hashtag = "climatechange", # hashtag name
                days = 900,   # ADJUST FOR HURRICANE DATE !!!!!!
                remap_output = True, # False for mobile app, True for web
                max_cursor = 4000) # max number of posts fetched,
                                  # cost is 1 unit per 200 posts

# %%
# convert json to dataframe
df = pd.json_normalize(result.data["posts"])

# %%
# extract relevant info
df = df[['itemInfos.id', 'itemInfos.createTime', 'itemInfos.authorId',
         'itemInfos.text', 'itemInfos.video.urls', 'itemInfos.shareCount',
         'itemInfos.playCount', 'itemInfos.commentCount']]

# rename columns
df.columns = ['id', 'createTime', 'authorId', 'text', 'video.urls',
              'shareCount', 'playCount', 'commentCount']

df["createTime"] = [str(datetime.fromtimestamp(int(i)).date())
                                                for i in df["createTime"]]

# %%
df

# %%
df = df[(df["createTime"] >= "2022-10-28") & (df["createTime"] <= "2022-11-28")]

# %%
# order by comment count
df = df.sort_values(by=['commentCount'], ascending=False).reset_index(drop=True)

# delete posts with less than 30 comments
df = df[df['commentCount'] >= 30]

# state how many
print(f'{len(df)} posts for hashtags with more than 30 comments')
# Out:
# 114 posts for hashtags with more than 30 comments

# %%
df['createTime'].unique()
# Out:
# array(['2022-10-24', '2022-10-14', '2022-09-24', '2022-10-19',
#        '2022-10-16', '2022-09-18', '2022-09-14', '2022-09-20',
#        '2022-10-17', '2022-09-30', '2022-09-15', '2022-09-23',
#        '2022-10-03', '2022-10-13', '2022-09-17', '2022-10-02',
#        '2022-10-08', '2022-10-18', '2022-10-12', '2022-10-05',
#        '2022-10-26', '2022-10-11', '2022-10-28', '2022-09-19',
#        '2022-09-16', '2022-09-28', '2022-09-29', '2022-10-10',
#        '2022-10-22', '2022-10-06', '2022-09-27', '2022-10-07',
#        '2022-09-26', '2022-10-01', '2022-09-25', '2022-10-20',
#        '2022-09-21', '2022-10-21'], dtype=object)

# %%
len(df['createTime'].unique())  # we take the comments of x days
# Out:
# 38

# %%
df = df.loc[df.groupby('createTime')['commentCount'].idxmax()]

# %%
# order df by date
df = df.sort_values(by=['createTime'], ascending=True).reset_index(drop=True)

df
# Out:
#                      id  createTime             authorId  \
# 0   7143344050417077509  2022-09-14  6606355564501762053
# 1   7143623069284748550  2022-09-15  6966234696955872261
# 2   7143962475757604101  2022-09-16  6757754163742032902
# 3   7144330799645543685  2022-09-17  7125391387152270341
# 4   7144573582440484122  2022-09-18  6928760643127264258
# 5   7144844623851064618  2022-09-19  6738446549145764869
# 6   7145493259815603461  2022-09-20  7144735520425526278
# 7   7145640089220222254  2022-09-21  6749773962819486726
# 8   7146396688104590634  2022-09-23  6643983493737791493
# 9   7146900341810810139  2022-09-24  6928760643127264258
# 10  7147314461160819995  2022-09-25  7102663280099017755
# 11  7147746563689893126  2022-09-26  6805177494955738117
# 12  7147939302440291627  2022-09-27  6993899054099432453
# 13  7148436887957540102  2022-09-28  6926940523131831301
# 14  7148609970748198190  2022-09-29  6643983493737791493
# 15  7149209471833820462  2022-09-30  6815828271440086022
# 16  7149420236008115457  2022-10-01    86406567985565696
# 17  7149908239491108101  2022-10-02  6890818260087505926
# 18  7150168141916540166  2022-10-03  6772259513095668742
# 19  7151033928864795909  2022-10-05  6886828060440937477
# 20  7151334610167794950  2022-10-06  6820806955948409862
# 21  7151545944952278318  2022-10-07  6934182930671797253
# 22  7152250702553779462  2022-10-08  7117878665807479814
# 23  7152671402192276742  2022-10-10  6905852130881111045
# 24  7153242827323919659  2022-10-11  6872372293688771590
# 25  7153721007835008298  2022-10-12  7108485386146317355
# 26  7154097477094870318  2022-10-13  6908840664314741766
# 27  7154373264914009350  2022-10-14  7053420124242658310
# 28  7155163691657350405  2022-10-16  6806511492025713669
# 29  7155539942368759083  2022-10-17  7108485386146317355
# 30  7155879504114715910  2022-10-18  6807877416234730501
# 31  7156301698414284037  2022-10-19  6886828060440937477
# 32  7156549294097435909  2022-10-20  6741335218266194949
# 33  7156922485236157701  2022-10-21  6832307469964887046
# 34  7157342934294170907  2022-10-22  6604413452785516546
# 35  7157913634226654466  2022-10-24  6743464067279258629
# 36  7158627404683054382  2022-10-26  7082830800441951278
# 37  7159681803257662762  2022-10-28  7082830800441951278
#
#                                                  text  \
# 0   #mtl was fun yesterday!! #mtltiktok #rain#inno...
# 1   Together we can still do it 🙏🏼🌎 #saveourplanet...
# 2   Forza Marche! 🇮🇹 #neiperte #climatechange #ita...
# 3   i haven’t posted in awhile #fyp #foryou #foryo...
# 4   #ทางออก #ทุกปัญหา #ทุกปัญหามีทางออก ไม่มีการชน...
# 5   Hurricane Fiona brought powerful winds and cat...
# 6   Why Climate Change Is Fake #climatechange #fyp...
# 7   #greenscreen the more we ignore our climate em...
# 8   Let's all just calm down and trust God to take...
# 9   #ประโยชน์ ของการ #กินมื้อเดียว #ยิ่งหิวยิ่งสุข...
# 10  Imagine sierra madre doing this #sierramadrelo...
# 11  How many plastic card have you eaten? 🥵 The re...
# 12  Replying to @tarabellerose We must keep fighti...
# 13  Does your ✨Cap1talism✨ subscription make you #...
# 14  What's the deal with all the comets and aliens...
# 15  Timelapse: Hurricane Ian #hurricane #hurricane...
# 16  They. Talk. Like. This. 🤣#nasdaily #travelvlog...
# 17  كيف يشرب الماء؟#وليد_سرحان #المؤسسة_الطبية_الع...
# 18  Hundreds of protestors from the climate campai...
# 19  A climate activist demonstrating in London gav...
# 20  L’ansia per il cambiamento climatico può esser...
# 21  DARK BRANDON RISES #climatechange #globalwarmi...
# 22  Stink bugs!  These critters have been alarming...
# 23  This warm weather is nice and all, but…is it w...
# 24  IM LOSING IT ACTUALLY OH MY GOD || #eddsworld ...
# 25  Nuclear fuel being moved from the reactor core...
# 26  light pollution- the glow from street and dome...
# 27  Just Stop Oil activists have spray painted the...
# 28  #juststopoil #Activist says there was "minimal...
# 29  This nuclear fuel assembly is glowing blue bec...
# 30  Replying to @ckey4343 Collab with @Greenpeace ...
# 31  The climate activist who threw soup over Vince...
# 32  Vedere l’AURORA BOREALE🌌❤️ @humansafari è pass...
# 33  Come funzionano gli autobus elettrici? Oggi lo...
# 34  Bersedia Kemungkinan Banjir Kilat Dan Hujan Ri...
# 35  What will be next, spaghetti on a Picasso? 🖼️ ...
# 36  Greenwashing (verb): when corporations claim t...
# 37  Climate action is fiscally responsible. #clima...
#
#                                            video.urls  shareCount  playCount  \
# 0   ['https://v77.tiktokcdn-eu.com/99fcbc45eec4fb3...        4790    5864825
# 1   ['https://v16m.tiktokcdn-eu.com/4f1314ce092dfc...        3736    2943007
# 2   ['https://v15m.tiktokcdn-eu.com/bf5de354933e63...         847     573977
# 3   ['https://v77.tiktokcdn-eu.com/4d701426728dd34...        2099    2300380
# 4   ['https://v16m.tiktokcdn-eu.com/7e7cf15b97d61c...        1174    2453440
# 5   ['https://v77.tiktokcdn-eu.com/81842ef0022218e...         546     762135
# 6   ['https://v77.tiktokcdn-eu.com/083cf56998330e7...        1029    1355917
# 7   ['https://api16-normal-c-useast2a.tiktokv.com/...         390     167931
# 8   ['https://v16m.tiktokcdn-eu.com/4708c843e7ebd4...        4456    1063001
# 9   ['https://v45.tiktokcdn-eu.com/b18d5df8f3a041f...       22101    4328050
# 10  ['https://v45.tiktokcdn-eu.com/b310030072ae94a...         423     558192
# 11  ['https://v45.tiktokcdn-eu.com/2574a97dcba72a0...         436     538067
# 12  ['https://v45.tiktokcdn-eu.com/69881c7347f0470...        1656     214355
# 13  ['https://v45.tiktokcdn-eu.com/6a8a1a04710a9f7...        6364     631694
# 14  ['https://v77.tiktokcdn-eu.com/e4f4fc64a061b9b...        1594     247665
# 15  ['https://v45.tiktokcdn-eu.com/52057f68a9b4022...       23912    4097309
# 16  ['https://v16m.tiktokcdn-eu.com/75c9e43b37d7f6...         404     872610
# 17  ['https://v45.tiktokcdn-eu.com/d1251bb2f0c07c6...       11207    3397104
# 18  ['https://v45.tiktokcdn-eu.com/f4c93a26c99f0f8...        1005    1561664
# 19  ['https://v45.tiktokcdn-eu.com/cb17fe4f26c0089...        1226    1447467
# 20  ['https://v77.tiktokcdn-eu.com/c1bed403b8e3a63...        1168   12513177
# 21  ['https://api16-normal-c-useast2a.tiktokv.com/...         719     160202
# 22  ['https://v77.tiktokcdn-eu.com/d6f008aa279b379...        9407     979119
# 23  ['https://v77.tiktokcdn-eu.com/b38d7147bfdd59f...        1182     563430
# 24  ['https://v16m.tiktokcdn-eu.com/78b6eb0e08e430...         464     206215
# 25  ['https://v16m.tiktokcdn-eu.com/55603b51794cf2...         886    2891834
# 26  ['https://sf16-ies-music-va.tiktokcdn.com/obj/...        2205    1240364
# 27  ['https://v77.tiktokcdn-eu.com/06d41914f6bc8ea...        2814    2277992
# 28  ['https://v77.tiktokcdn-eu.com/0e7427295fc619b...        3824    2512302
# 29  ['https://v45.tiktokcdn-eu.com/a5eb105fe4a0eda...        2692   11645085
# 30  ['https://v45.tiktokcdn-eu.com/b755e4e81b22eff...         606     889806
# 31  ['https://v45.tiktokcdn-eu.com/c8779511f9729f4...        6948    4241755
# 32  ['https://v45.tiktokcdn-eu.com/a5c1da4fb4036a0...        3512    1469768
# 33  ['https://v77.tiktokcdn-eu.com/04dc8524710dce4...         120     279167
# 34  ['https://v45.tiktokcdn-eu.com/c45b12ad972ebd9...       10041    1332025
# 35  ['https://v45.tiktokcdn-eu.com/c2d4f6f907b62a2...        5343    6376439
# 36  ['https://v16m.tiktokcdn-eu.com/d3dbbd85455827...         770     387533
# 37  ['https://v45.tiktokcdn-eu.com/d4ef38713bf4d93...         386     400246
#
#     commentCount
# 0           4972
# 1           3036
# 2            961
# 3           2339
# 4           5011
# 5            972
# 6           4784
# 7            305
# 8           2829
# 9           6987
# 10           456
# 11           555
# 12           719
# 13           865
# 14           864
# 15          3307
# 16           538
# 17          2335
# 18          2749
# 19          1368
# 20           728
# 21           577
# 22          2050
# 23           819
# 24          1151
# 25          1744
# 26          2482
# 27          9161
# 28          6819
# 29          3365
# 30          2048
# 31          6826
# 32           335
# 33           233
# 34           787
# 35         12497
# 36          1319
# 37           993

# %%
df.to_csv('climatechange_ian_posts.csv', index=False)
